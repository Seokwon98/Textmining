# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np
import pandas as pd

# %%
df1970 = pd.read_csv('/content/drive/MyDrive/텍스트마이닝/1970년대.csv', encoding = "cp949")
df8090 = pd.read_csv('/content/drive/MyDrive/텍스트마이닝/1980-1990.csv', encoding = "cp949")
df2000 = pd.read_csv('/content/drive/MyDrive/텍스트마이닝/2000년대.csv') #encoding = "cp949")
df2010 = pd.read_csv('/content/drive/MyDrive/텍스트마이닝/2010년대.csv') #encoding = "cp949")
df2020 = pd.read_csv('/content/drive/MyDrive/텍스트마이닝/2020년대.csv') #encoding = "cp949")

df2000
# Out:
#      Unnamed: 0  year  rank                      name     genre  \
# 0             0  2000     1                      아시나요       발라드
# 1             1  2000     2                     다 줄거야       발라드
# 2             2  2000     3                Run To You  댄스, 랩/힙합
# 3             3  2000     4                       거짓말       발라드
# 4             4  2000     5                        초련        댄스
# ..          ...   ...   ...                       ...       ...
# 195         195  2009    16                   소원을 말해봐        댄스
# 196         196  2009    17                    사랑한 후에       발라드
# 197         197  2009    18  헤어지지 못하는 여자, 떠나가지 못하는 남자      랩/힙합
# 198         198  2009    19                     토요일밤에        댄스
# 199         199  2009    20                 Hot Issue        댄스
#
#                                               lyricist  \
# 0                                                  강은경
# 1                                                  조규만
# ...

# %%
df2000['lyrics'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df2010['lyrics'].replace(r'\s+|\\n', ' ', regex=True, inplace=True) 
df2020['lyrics'].replace(r'\s+|\\n', ' ', regex=True, inplace=True) 
df1970['Lyrics'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df8090['Lyrics'].replace(r'\s+|\\n', ' ', regex=True, inplace=True) 
df1970['Lyrics'].replace('~', ' ', regex=True, inplace=True)
df1970['Lyrics'].replace('-', ' ', regex=True, inplace=True)
df1970['Lyrics'].replace('<', ' ', regex=True, inplace=True)
df1970['Lyrics'].replace('>', ' ', regex=True, inplace=True)
#df8090['Lyrics'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)

# %%
df1970 = df1970
df1980 = df8090.iloc[0:100]
df1990 = df8090.iloc[100:]
#df0006 = df.iloc[0:140]
#df0712 = df.iloc[140:260]
#df1316 = df.iloc[260:340]
#df1722 = pd.concat([df.iloc[340:410]],[df.iloc[430:]])
#df2010 = df.iloc[200:400]

df1980
# Out:
#     Unnamed: 0  Year  Rank             Name  Artist          Genre  \
# 0            0  1980     1  가까이 하기엔 너무 먼 당신     이광조            발라드
# 1            1  1980     2             가나다라     송창식         포크/블루스
# 2            2  1980     3             가슴앓이     한마음            발라드
# 3            3  1980     4             가시나무  시인과 촌장            발라드
# 4            4  1980     5     가을을 남기고 간 사랑     패티김       성인가요/트로트
# ..         ...   ...   ...              ...     ...            ...
# 95          95  1980    96           행복한 사람     조동진         포크/블루스
# 96          96  1980    97               허공     조용필       성인가요/트로트
# 97          97  1980    98         홀로 된다는 것     변진섭            발라드
# 98          98  1980    99              희나리     구창모  발라드, 성인가요/트로트
# 99          99  1980   100              J에게     이선희            발라드
#
#                                                Lyrics
# 0   아 당신은 당신은 누구시길래 내 맘 깊은 곳에 외로움 심으셨나요 그냥 스처 지나갈 ...
# ...

# %%
df1970.drop(['Unnamed: 0'], axis = 1, inplace = True)
df1970
# Out:
#     Year  Rank      Name Artist     Genre  \
# 0   1970     1   가을비 우산속     최헌  성인가요/트로트
# 1   1970     2       감수광    혜은이  성인가요/트로트
# 2   1970     3      개구장이    산울림      록/메탈
# 3   1970     4      개 여울    정미조  성인가요/트로트
# 4   1970     5    고귀한 선물    장은아    포크/블루스
# ..   ...   ...       ...    ...       ...
# 91  1970    96       한사람    양희은    포크/블루스
# 92  1970    97    한잔의 추억    이장희    포크/블루스
# 93  1970    98      해뜰 날    송대관  성인가요/트로트
# 94  1970    99    해변의 여인    나훈아  성인가요/트로트
# 95  1970   100  휘파람을 부세요    정미조       발라드
#
#                                                Lyrics
# 0   그리움이 눈처럼 쌓인 거리를 나혼자서 걸었네 미련때문에 흐르는 세월따라 잊혀진 그 ...
# 1   바람부는 제주에는 돌도 많지만 인정많고 마음씨 고운 아가씨도 많지요 감수광 감수광 ...
# 2   우리 같이 놀아요 뜀을 뛰며 공을 차며 놀아요 우리 같이 불러요 예쁜 노래 고운 노...
# 3   당신은 무슨 일로 그리합니까 홀로이 개여울에 주저 앉아서 파릇한 풀포기가 돋아 나오...
# 4   갈매기 날으는 바닷가에도 그대가 없으면 쓸쓸하겠네 파도가 밀려와 속삭여줄때도 그대가...
# ..                                                ...
# 91  한사람 여기 또 그곁에 둘이 서로 바라보며 웃네 먼훗날 위해 내미는 손 둘이 서로 ...
# ...

# %%
df1980.drop(['Unnamed: 0'], axis = 1, inplace = True)
df1990.drop(['Unnamed: 0'], axis = 1, inplace = True)
df2000.drop(['Unnamed: 0'], axis = 1, inplace = True)
df2010.drop(['Unnamed: 0'], axis = 1, inplace = True)
df2020.drop(['Unnamed: 0'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1980
# Out:
#     Year  Rank             Name  Artist          Genre  \
# 0   1980     1  가까이 하기엔 너무 먼 당신     이광조            발라드
# 1   1980     2             가나다라     송창식         포크/블루스
# 2   1980     3             가슴앓이     한마음            발라드
# 3   1980     4             가시나무  시인과 촌장            발라드
# 4   1980     5     가을을 남기고 간 사랑     패티김       성인가요/트로트
# ..   ...   ...              ...     ...            ...
# 95  1980    96           행복한 사람     조동진         포크/블루스
# 96  1980    97               허공     조용필       성인가요/트로트
# 97  1980    98         홀로 된다는 것     변진섭            발라드
# 98  1980    99              희나리     구창모  발라드, 성인가요/트로트
# 99  1980   100              J에게     이선희            발라드
#
#                                                Lyrics
# 0   아 당신은 당신은 누구시길래 내 맘 깊은 곳에 외로움 심으셨나요 그냥 스처 지나갈 ...
# 1   가나다라마바사 아자차카타파하 헤이헤이 하고싶은 말들은 너무너무 많은데 이 내 노래는...
# 2   밤별들이 내려와 창문틈에 머물고 너의 맘이 다가와 따뜻하게 나를 안으며 예전부터 내...
# 3   내속엔 내가 너무도 많아 당신에 쉴곳 없네 내속엔 헛된 바람들로 당신에 편할곳 없네...
# ...

# %%
#okt = Okt()
#words = " ".join(df['lyrics'].tolist())
#words = okt.morphs(words,stem=True)

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 596 kB/s
# ...
#      |████████████████████████████████| 465 kB 42.3 MB/s
# ...

# %%
from konlpy.tag import Okt

okt = Okt()
words = " ".join(df1970['Lyrics'].tolist())
words = okt.morphs(words,stem=True)

# %%
#remove_one_word = [x for x in words if len(x)>1]
#len(remove_one_word)
# Out:
# 23625

# %%
words1 = " ".join(df1970['Lyrics'].tolist())
words1 = okt.pos(words1, join=True)

# %%
len(words1)
# Out:
# 9635

# %%
#from collections import Counter
#frequent = Counter(remove_one_word).most_common()
#frequent

# %%
with open('/content/drive/MyDrive/텍스트마이닝/stopwords.txt', 'r',encoding='cp949') as f:
    list_file = f.readlines()
stopwords = list_file[0].split(",")
remove_stopwords = [x for x in words if x not in stopwords]
len(remove_stopwords)
print([l.strip() for l in remove_stopwords])
# Out:
# ['그리움', '눈', '쌓이다', '거리', '걸다', '미련', '흐르다', '세월', '따르다', '잊혀지다', '얼굴', '이다지', '속눈썹', '또다시', '떠오르다', '정다웠던', '눈길', '목소리', '어딜', '아프다', '가슴', '달래다', '찾다', '헤매다', '가을비', '우산', '속', '이슬', '맺힌다', '잊다', '늘다', '세월', '흐름', '속', '잊다', '잊다', '슬픔', '그리움', '잊다', '그러다가', '늘다', '잊다', '정다웠던', '눈길', '목소리', '어딜', '아프다', '가슴', '달래다', '찾다', '헤매다', '가을비', '우산', '속', '이슬', '맺힌다', '바람', '불다', '제주', '돌다', '많다', '인정', '많다', '마음씨', '곱다', '아가씨', '많다', '감수', '광', '감수', '광', '어떡하다', '렝', '감수', '광', '설릉사', '보내다', '엥', '혼', '조', '옵', '서예', '겨울', '한라산', '눈', '덮이다', '사이', '봄', '한창', '라오', '감수', '광', '감수', '광', '어떡하다', '렝', '감수', '광', '설릉사', '보내다', '엥', '혼', '조', '옵', '서예', '어쩌다가', '나르다', '떠나다', '다해', '잊다', '그리다', '돌아오다', '서예', '감수', '광', '감수', '광', '어떡하다', '렝', '감수', '광', '설릉사', '보내다', '엥', '혼', '조', '옵', '서예', '놀다', '뛰다', '뛰다', '공', '차다', '놀다', '불다', '예쁘다', '노래', '곱다', '노래', '불다', '이마', '땀방울', '마음', '꽃', '방울', '나무', '하늘', '개구쟁이', '놀다', '뛰다', '뛰다', '공', '차다', '놀다', '불다', '예쁘다', '노래', '곱다', '노래', '불다', '이마', '땀방울',
# ...

# %%
#Counter(remove_stopwords).most_common()

# %%
song1 = df1980['Lyrics']

# %%
song1
# Out:
# 0     아 당신은 당신은 누구시길래 내 맘 깊은 곳에 외로움 심으셨나요 그냥 스처 지나갈 ...
# 1     가나다라마바사 아자차카타파하 헤이헤이 하고싶은 말들은 너무너무 많은데 이 내 노래는...
# 2     밤별들이 내려와 창문틈에 머물고 너의 맘이 다가와 따뜻하게 나를 안으며 예전부터 내...
# 3     내속엔 내가 너무도 많아 당신에 쉴곳 없네 내속엔 헛된 바람들로 당신에 편할곳 없네...
# 4     가을을 남기고 떠난 사람 겨울은 아직 멀리 있는데 사랑할 수록 깊어가는 슬픔에 눈물...
#                             ...
# 95    울고 있나요 당신은 울고 있나요 아 그러나 당신은 행복한 사람 아직도 남은 별 찾을...
# 96    꿈이었다고 생각하기엔 너무나도 아쉬움 남아 가슴태우며 기다리기엔 너무나도 멀어진 그...
# 97    아주 덤덤한 얼굴로 나는 뒤돌아 섰지만 나에 허무한 마음은 가눌 길이 없네 아직 못...
# 98    사랑함에 세심했던 나의 마음이 그렇게도 그대에겐 구속이었소 믿지못해 그런 것이 아니...
# 99    J 스치는 바람에 J 그대 모습 보이면 난 오늘도 조용히 그댈 그리워하네 J 지난밤...
# Name: Lyrics, Length: 100, dtype: object

# %%
import gensim
from gensim.corpora.dictionary import Dictionary
from gensim import corpora, models

# %%
Lyrics_data = list(df1970.Lyrics)
Lyrics_data[0:5]
# Out:
# ['그리움이 눈처럼 쌓인 거리를 나혼자서 걸었네 미련때문에 흐르는 세월따라 잊혀진 그 얼굴이 왜 이다지 속눈썹에 또다시 떠오르나 정다웠던 그 눈길 목소리 어딜갔나 아픈 가슴 달래며 찾아 헤매이는 가을비 우산속에 이슬 맺힌다 잊어야지 언젠가는 세월 흐름 속에 나혼자서 잊어야지 잊어봐야지 슬픔도 그리움도 나혼자서 잊어야지 그러다가 언젠가는 잊어지겠지 정다웠던 그 눈길 목소리 어딜갔나 아픈 가슴 달래며 찾아 헤매이는 가을비 우산속에 이슬 맺힌다',
#  '바람부는 제주에는 돌도 많지만 인정많고 마음씨 고운 아가씨도 많지요 감수광 감수광 나어떡할렝 감수광 설릉사랑 보낸시엥 가거들랑 혼조옵서예 겨울 오는 한라산에 눈이 덮여도 당신 하고 나 사이에는 봄이 한창이라오 감수광 감수광 나어떡할렝 감수광 설릉사랑 보낸시엥 가거들랑 혼조옵서예 어쩌다가 나를 두고 떠난다해도 못잊어 그리우면 혼자 돌아옵서예 감수광 감수광 나어떡할렝 감수광 설릉사랑 보낸시엥 가거들랑 혼조옵서예',
#  '우리 같이 놀아요 뜀을 뛰며 공을 차며 놀아요 우리 같이 불러요 예쁜 노래 고운 노래 불러요 이마엔 땀방울 마음엔 꽃방울 나무에 오를래 하늘에 오를래 개구쟁이 우리 같이 놀아요 뜀을 뛰며 공을 차며 놀아요 우리 같이 불러요 예쁜 노래 고운 노래 불러요 이마엔 땀방울 마음엔 꽃방울 나무에 오를래 하늘에 오를래 개구쟁이',
#  '당신은 무슨 일로 그리합니까 홀로이 개여울에 주저 앉아서 파릇한 풀포기가 돋아 나오고 잔물이 봄바람에 헤적일때에 가도 아주 가지는 않노라시던 그런 약속이 있었겠지요 날마다 개여울에 나와 앉아서 하염없이 무엇을 생각합니다 가도 아주 가지는 않노라심은 굳이 잊지 말라는 부탁인지요 가도 아주 가지는 않노라시던 그런 약속이 있었겠지요 날마다 개여울에 나와 앉아서 하염없이 무엇을 생각합니다 가도 아주 가지는 않노라심은 굳이 잊지 말라는 부탁인지요',
# ...

# %%
from konlpy.tag import Kkma
Kkma = Kkma()

# %%
import re

dataset =[]
for i in range(len(Lyrics_data)):
    dataset.append(Kkma.nouns(re.sub('[^가-힣a-zA-Z\s]','',Lyrics_data[i])))
# Out:
# <>:5: DeprecationWarning: invalid escape sequence \s
# <>:5: DeprecationWarning: invalid escape sequence \s
# <>:5: DeprecationWarning: invalid escape sequence \s
# <ipython-input-80-dcfbbdd5b90e>:5: DeprecationWarning: invalid escape sequence \s
#   dataset.append(Kkma.nouns(re.sub('[^가-힣a-zA-Z\s]','',Lyrics_data[i])))

# %%
lyrics_1970 = dataset

lyrics_1970 = [[y for y in x if not len(y)==1]
              for x in lyrics_1970]
dictionary = corpora.Dictionary(lyrics_1970)
corpus = [dictionary.doc2bow(text) for text in lyrics_1970]

# %%
import matplotlib.pyplot as plt
from gensim.models import CoherenceModel

coherence_values=[]
for i in range(2,15):
    ldamodel=gensim.models.ldamodel.LdaModel(corpus, num_topics=i, id2word=dictionary)
    coherence_model_lda=CoherenceModel(model=ldamodel, texts=lyrics_1970, dictionary=dictionary, topn=10)
    coherence_lda=coherence_model_lda.get_coherence()
    coherence_values.append(coherence_lda)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...

# %%
x=range(2,15)
plt.plot(x, coherence_values)
plt.xlabel("number of topics")
plt.ylabel("coherence score")
plt.show()

# %%
perplexity_values=[]
for i in range(2,20):
    ldamodel=gensim.models.ldamodel.LdaModel(corpus, num_topics=i, id2word=dictionary)
    perplexity_values.append(ldamodel.log_perplexity(corpus))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...

# %%
x=range(2,20)
plt.plot(x, perplexity_values)
plt.xlabel("number of topics")
plt.ylabel("perplextity score")
plt.show()

# %%
import konlpy

# tokenization 함수를 만들어둠
def tokenize_korean_text(text):
    text = re.sub(r'[^,.?!\w\s]','', text)  ## ,.?!와 문자+숫자+_(\w)와 공백(\s)만 남김  # 앞에 r을 붙여주면 deprecation warning이 안뜸 (raw string으로 declare)
    
    okt = konlpy.tag.Okt()
    Okt_morphs = okt.pos(text, stem = True)   # stem=True로 설정하면 동사원형으로 바꿔서 return
    
    words = []
    for word, pos in Okt_morphs:
        if pos == 'Adjective' or pos == 'Verb' or pos == 'Noun':  # 이 경우에는 형용사, 동사, 명사만 남김
            words.append(word)

    words_str = ' '.join(words)
    return words_str


# 가사를 하나씩 tokenize해서 list로 저장
tokenized_list = []

for text in df2010['lyrics']:
    tokenized_list.append(tokenize_korean_text(text))

print(len(tokenized_list))
print(tokenized_list[0])
# Out:
# 200
# 앞 한마디 하다 뒤 내 얘길 안 좋다 해 차다 어이 없다 나 같다 이다 처음 보다 것 같다 왜 나르다 판단 하다 내 혹시 두렵다 겉 속 나르다 자다 알다 하다 내 겉모습 보다 한심하다 여자 보다 너 시선 난 웃기다 춤추다 땐 사랑 춤추다 내 모습 볼 때 넋 놓다 보고서 끝나다 손가락질 하다 그 위선 난 웃기다 이렇다 옷 이렇다 머리 모양 이렇다 춤 추다 여자 뻔하다 네 더 뻔하다 자신 없다 저 뒤 뒤 뒤 물러서다 되다 왜 자꾸 떠들다 네 속이다 훤히 보이다 건 아니다 겉 속 나르다 자다 알다 하다 내 겉모습 보다 한심하다 여자 보다 너 시선 난 웃기다 춤추다 땐 사랑 춤추다 내 모습 볼 때 넋 놓다 보고서 끝나다 손가락질 하다 그 위선 난 웃기다 날 감당 하다 수 있다 남다 찾다 진짜 남자 찾다 말로 남자 다운 척 하다 남자 날 불안하다 하다 않다 남다 없다 자신감 넘치다 내 나일 수 있다 자유롭다 두다 멀리 바라보다 겉 속 나르다 자다 알다 하다 내 겉모습 보다 한심하다 여자 보다 너 시선 난 웃기다 춤추다 땐 사랑 춤추다 내 모습 볼 때 넋 놓다 보고서 끝나다 손가락질 하다 그 위선 난 웃기다

# %%
drop_corpus = []

for index in range(len(tokenized_list)):
    corpus = tokenized_list[index]
    if len(set(corpus.split())) < 3:   # 같은 단어 1-2개만 반복되는 corpus도 지우기 위해 set()을 사용
        df2010.drop(index, axis='index', inplace=True)
        drop_corpus.append(corpus)
    
for corpus in drop_corpus:
    tokenized_list.remove(corpus)

df2010.reset_index(drop=True, inplace=True)

print(len(tokenized_list))
print(len(df2010))
# Out:
# 200
# 200

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
#LDA 는 Count기반의 Vectorizer만 적용 
count_vectorizer = CountVectorizer(max_df=0.1, max_features=1000, min_df=2, ngram_range=(1,2))
    # 2개의 문서 미만으로 등장하는 단어는 제외, 전체의 10% 이상으로 자주 등장하는 단어는 제외
    # bigram도 포함

feat_vect = count_vectorizer.fit_transform(tokenized_list)
print('CountVectorizer Shape:', feat_vect.shape)
# Out:
# CountVectorizer Shape: (200, 1000)

# %%
lda = LatentDirichletAllocation(n_components=14)  # 토픽 수는 14개로 설정
lda.fit(feat_vect)
# Out:
# LatentDirichletAllocation(n_components=14)

# %%
LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
             evaluate_every=-1, learning_decay=0.7,
             learning_method='batch', learning_offset=10.0,
             max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
             n_components=14, n_jobs=None, perp_tol=0.1,
             random_state=None, topic_word_prior=None,
             total_samples=1000000.0, verbose=0)
# Out:
# LatentDirichletAllocation(n_components=14)

# %%
def display_topics(model, feature_names, num_top_words):
    for topic_index, topic in enumerate(model.components_):
        print('Topic #', topic_index)

        # components_ array에서 가장 값이 큰 순으로 정렬했을 때, 그 값의 array index를 반환. 
        topic_word_indexes = topic.argsort()[::-1]
        top_indexes=topic_word_indexes[:num_top_words]
        
        # top_indexes대상인 index별로 feature_names에 해당하는 word feature 추출 후 join으로 concat
        feature_concat = ' '.join([feature_names[i] for i in top_indexes])                
        print(feature_concat)

# CountVectorizer객체내의 전체 word들의 명칭을 get_features_names( )를 통해 추출
feature_names = count_vectorizer.get_feature_names()

# Topic별 가장 연관도가 높은 word를 10개만 추출
display_topics(lda, feature_names, 10)
# Out:
# Topic # 0
# 아래 하다 않다 흔들다 안녕 갈다 가다 모르다 오늘 우리 않다 사랑 마치 끌리다
# Topic # 1
# 나가다 바다 제일 좋아하다 문제 지나가다 뻔하다 듯이 그녀 미안하다
# Topic # 2
# 없다 없다 그녀 좋아하다 어리다 알다 사람 돌다 노랗다 파란 어른 뛰다
# Topic # 3
# 울다 목소리 수도 수도 없다 거울 때문 상처 기쁘다 잊어버리다 듣다 노래
# Topic # 4
# 항상 빨다 한단 사랑 한단 고백 하다 그대 아름답다 당신 라며 이번
# Topic # 5
# 그땐 울다 그땐 그땐 돌아오다 돌아가다 잠들다 그리다 원하다 차갑다 틀다
# Topic # 6
# 나나 나나 나나 뜨겁다 그만하다 흔들다 이야기 죽다 뻔하다 걱정 그대로
# Topic # 7
# 이름 운명 향기 살아가다 몰래 영원하다 다가가다 훔치다 사이 우주
# Topic # 8
# 반하다 좋다 하다 자꾸만 내일 준비 열리다 커지다 새다 마지막 마지막 버리다 마음
# Topic # 9
# 벚꽃 오빠 먹다 잠들다 내리다 별빛 봄바람 지나가다 반복 떨어지다
# Topic # 10
# 빛나다 흔들다 입다 짧다 모든 순간 그립다 그립다 아무렇다 가르치다 느끼다 어서
# Topic # 11
# 싶다 보고 변하다 겨울 추다 건지다 춤추다 하다 우리 자다 알다 머물다 갈다
# Topic # 12
# 달라 입술 그녀 나나 티비 어떡하다 맞추다 끄다 치다 나나 나나
# Topic # 13
# 쉬다 차라리 사이 흔들다 내겐 입술 달콤하다 없다 하다 거기 제발
# ...

# %%
pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.7 MB 6.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/sklearn/
# ...
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=f0ce5de8424649608f2979f176aa5736235a306356673d8cd80a27a585c4c42c
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=b76e145ef99fe342195fbe83136d3e3ccf3a4a558f68772d2931d41b7df6e2ab
# ...

# %%
import pyLDAvis.sklearn  # sklearn의 ldamodel에 최적화된 라이브러리

pyLDAvis.enable_notebook()
vis = pyLDAvis.sklearn.prepare(lda, feat_vect, count_vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el761404883300427043086789221"></div>
# <script type="text/javascript">
#
# ...

# %%
# 문서별로, 가장 확률이 높은 topic으로 할당해줌

doc_topic = lda.transform(feat_vect)

doc_per_topic_list = []
for n in range(doc_topic.shape[0]):
    topic_most_pr = doc_topic[n].argmax()
    topic_pr = doc_topic[n].max()
    doc_per_topic_list.append([n, topic_most_pr, topic_pr])
    
doc_topic_df = pd.DataFrame(doc_per_topic_list, columns=['Doc_Num', 'Topic', 'Percentage'])

doc_topic_df.head()
# Out:
#    Doc_Num  Topic  Percentage
# 0        0     11    0.977352
# 1        1      6    0.986345
# 2        2     13    0.596899
# 3        3      9    0.560613
# 4        4      6    0.974206

# %%
doc_topic_df = doc_topic_df.join(df2010)
doc_topic_df.head()
# Out:
#    Doc_Num  Topic  Percentage  year  rank                name genre lyricist  \
# 0        0     11    0.977352  2010     1  Bad Girl Good Girl    댄스      박진영
# 1        1      6    0.986345  2010     2                 잔소리   발라드      김이나
# 2        2     13    0.596899  2010     3           죽을 만큼 아파서  랩/힙합      박장근
# 3        3      9    0.560613  2010     4                  못해   발라드      민연재
# 4        4      6    0.974206  2010     5            죽어도 못 보내   발라드      방시혁
#
#                                               lyrics
# 0  You don't know me You don't know me You don't ...
# 1  늦게 다니지좀 마 술은 멀리좀 해봐 열살짜리 애처럼 말을 안듣니 정말 웃음만 나와 ...
# 2  I found the way to let you leave I never reall...
# 3  이제는 밥을 먹어도 눈물없이는 삼키지 못해 억지로 먹고 먹어도 속이 늘 허전해 노랠...
# 4  어려도 아픈건 똑같아 세상을 잘 모른다고 아픈걸 모르진 않아 괜찮아 질거라고 왜 거...

# %%
doc_topic_df.groupby('Topic')[['Doc_Num']].count()
# Out:
#        Doc_Num
# Topic
# 0           13
# 1           17
# 2           13
# 3           16
# 4           17
# 5           15
# 6           12
# 7           17
# 8           10
# 9           19
# 10          17
# 11          14
# 12           7
# 13          13

# %%
#토픽별로, 가장 높은 확률로 할당된 문서 top 3 확인
for topic in range(len(doc_topic_df['Topic'].unique())):
    print('Topic #', topic, '-----------------------------')
    top_pr_topics = doc_topic_df[doc_topic_df['Topic'] == topic].sort_values(by='Percentage', ascending=False)
    print(top_pr_topics['lyrics'].iloc[0])
    print(top_pr_topics['lyrics'].iloc[1])
    print(top_pr_topics['lyrics'].iloc[2])
    print(top_pr_topics['lyrics'].iloc[3], '\n')
# Out:
# Topic # 0 -----------------------------
# ...

# %%
doc_topic_df = doc_topic_df.replace({'Topic':0},'사랑 고백')
doc_topic_df = doc_topic_df.replace({'Topic':6},'이별에 대한 슬픔')
doc_topic_df = doc_topic_df.replace({'Topic':7},'사랑에 대한 아픔')


#doc_topic_df = doc_topic_df.drop(['Unnamed: 0'], axis = 1, inplace = True)
doc_topic_df
# Out:
#      Doc_Num      Topic  Percentage  year  rank                name  \
# 0          0         11    0.977352  2010     1  Bad Girl Good Girl
# 1          1          2    0.986345  2010     2                 잔소리
# 2          2         10    0.983990  2010     3           죽을 만큼 아파서
# 3          3         12    0.977352  2010     4                  못해
# 4          4          2    0.974206  2010     5            죽어도 못 보내
# ..       ...        ...         ...   ...   ...                 ...
# 195      195  사랑에 대한 아픔    0.983990  2019    16     이 노래가 클럽에서 나온다면
# 196      196  사랑에 대한 아픔    0.983709  2019    17                포장마차
# 197      197          9    0.985931  2019    18               나만, 봄
# 198      198         12    0.364001  2019    19                  사계
# 199      199          9    0.978405  2019    20                  안녕
#
#             genre     lyricist  \
# 0              댄스          박진영
# 1             발라드          김이나
# 2            랩/힙합          박장근
# ...

# %%
doc_topic_df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
doc_topic_df
# Out:
#     Doc_Num      Topic  Percentage  Year  Rank                     Name  \
# 0         0  이별에 대한 걱정    0.981060  1990     1  내사랑 내곁에 (응답하라 1988 삽입곡)
# 1         1         지침    0.974024  1990     2                   너를 사랑해
# 2         2          2    0.978858  1990     3                 다시만난 너에게
# 3         3          9    0.978354  1990     4                    나의 노래
# 4         4  이별에 대한 걱정    0.975429  1990     5               아주 오래된 연인들
# ..      ...        ...         ...   ...   ...                      ...
# 95       95          7    0.972450  1990    96               내가 너를 느끼듯이
# 96       96          9    0.974747  1990    97              추억의 책장을 넘기면
# 97       97         지침    0.984326  1990    98                       사계
# 98       98      시련/아픔    0.976689  1990    99                   사랑의 서약
# 99       99      시련/아픔    0.983766  1990   100                    어떤 이별
#
#         Artist   Genre                                             Lyrics
# ...

# %%
doc_topic_df.groupby('Topic')[['Doc_Num']].count()
# Out:
#            Doc_Num
# Topic
# 1                8
# 2               16
# 3               17
# 4               12
# 5               13
# 8                8
# 9               16
# 10               9
# 11               9
# 12              18
# 13              14
# 사랑 고백           20
# 사랑에 대한 아픔       22
# 이별에 대한 슬픔       18
